# %% [markdown]
# <a href="https://colab.research.google.com/github/ernxtorios/python-challenges/blob/main/advanced_pandas.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from google.colab import drive

# %%
import pandas as pd

# %%
drive.mount("/content/gdrive/")
# Out:
# Mounted at /content/gdrive/

# %%
file_path_movies = "/content/gdrive/MyDrive/datasources/movies.csv"

df_movies = pd.read_csv(file_path_movies)

df_movies
# Out:
#        movie                                             title  \
# 0     108583                               Fawlty Towers (1975
# 1      32898     Trip to the Moon, A (Voyage dans la lune, Le)
# 2       7065                            Birth of a Nation, The
# 3       7243  Intolerance: Love's Struggle Throughout the Ages
# 4      62383                      20,000 Leagues Under the Sea
# ...      ...                                               ...
# 9120  110748                                       Wake Wood (
# 9121  143410                                              Hyen
# 9122  151307                                The Lovers and the
# 9123  162376                                          Stranger
# 9124  164979                                   Women of '69, U
#
#                                genres  year  Rating  Rotton Tomato
# 0                              Comedy -1980       1             54
# 1     Action|Adventure|Fantasy|Sci-Fi  1902       7             80
# ...

# %%
df_movies.head(5)
# Out:
#     movie                                             title  \
# 0  108583                               Fawlty Towers (1975
# 1   32898     Trip to the Moon, A (Voyage dans la lune, Le)
# 2    7065                            Birth of a Nation, The
# 3    7243  Intolerance: Love's Struggle Throughout the Ages
# 4   62383                      20,000 Leagues Under the Sea
#
#                             genres  year  Rating  Rotton Tomato
# 0                           Comedy -1980       1             54
# 1  Action|Adventure|Fantasy|Sci-Fi  1902       7             80
# 2                        Drama|War  1915       6             92
# 3                            Drama  1915       4             82
# 4          Action|Adventure|Sci-Fi  1915       9             92

# %%
df_movies.tail(5)
# Out:
#        movie               title                genres  year  Rating  \
# 9120  110748         Wake Wood (  Drama|Horror|Mystery  1927       4
# 9121  143410                Hyen    (no genres listed)  1928       9
# 9122  151307  The Lovers and the    (no genres listed)  1929       8
# 9123  162376            Stranger                 Drama  1930       4
# 9124  164979     Women of '69, U           Documentary  1931       5
#
#       Rotton Tomato
# 9120             83
# 9121             58
# 9122             97
# 9123             76
# 9124             68

# %% [markdown]
# ### Renombrar columnas

# %%
df_movies = df_movies.rename(columns={"Rating": "rating", "Rotton Tomato": "rotton_tomato"})

df_movies
# Out:
#        movie                                             title  \
# 0     108583                               Fawlty Towers (1975
# 1      32898     Trip to the Moon, A (Voyage dans la lune, Le)
# 2       7065                            Birth of a Nation, The
# 3       7243  Intolerance: Love's Struggle Throughout the Ages
# 4      62383                      20,000 Leagues Under the Sea
# ...      ...                                               ...
# 9120  110748                                       Wake Wood (
# 9121  143410                                              Hyen
# 9122  151307                                The Lovers and the
# 9123  162376                                          Stranger
# 9124  164979                                   Women of '69, U
#
#                                genres  year  rating  rotton_tomato
# 0                              Comedy -1980       1             54
# 1     Action|Adventure|Fantasy|Sci-Fi  1902       7             80
# ...

# %% [markdown]
# ### Filtrado
# A menudo, querrá seleccionar un subconjunto de filas que cumplan ciertos criterios. Esto se puede lograr especificando: df[bool_array], donde bool_array representa una serie de valores verdaderos y falsos para cada fila.
#
# Las filas que evalúan como verdaderos se conservan, mientras que las que evalúan como falsos no.

# %%
df_movies["rating"] == 5
# Out:
# 0       False
# 1       False
# 2       False
# 3       False
# 4       False
#         ...
# 9120    False
# 9121    False
# 9122    False
# 9123    False
# 9124     True
# Name: rating, Length: 9125, dtype: bool

# %%
df_movies["rotton_tomato"]
# Out:
# 0       54
# 1       80
# 2       92
# 3       82
# 4       92
#         ..
# 9120    83
# 9121    58
# 9122    97
# 9123    76
# 9124    68
# Name: rotton_tomato, Length: 9125, dtype: int64

# %%
df_movies_drama = df_movies[df_movies["genres"] == "Drama"]

df_movies_drama
# Out:
#        movie                                             title genres  year  \
# 3       7243  Intolerance: Love's Struggle Throughout the Ages  Drama  1915
# 25      4405                Last Laugh, The (Letzte Mann, Der)  Drama  1924
# 29     25753                                             Greed  Drama  1923
# 38       957                               Scarlet Letter, The  Drama  1926
# 43    121618                                  The Great Gatsby  Drama  1926
# ...      ...                                               ...    ...   ...
# 9075  155392                           Hello, My Name Is Doris  Drama  2016
# 9078  156387                                       Sing Street  Drama  2015
# 9101  160656                                          Tallulah  Drama  2016
# 9113    7789                    \11'09\"\"01 - September 11 ("  Drama  1920
# 9123  162376                                          Stranger  Drama  1930
#
#       rating  rotton_tomato
# ...

# %%
df_movies_drama_100 = df_movies[(df_movies["genres"] == "Drama") & (df_movies["rotton_tomato"] == 100)]

df_movies_drama_100
# Out:
#        movie                                              title genres  year  \
# 192      954                       Mr. Smith Goes to Washington  Drama  1938
# 518     2848  Othello (Tragedy of Othello: The Moor of Venic...  Drama  1952
# 613      982                                             Picnic  Drama  1955
# 659      820        Death in the Garden (Mort en ce jardin, La)  Drama  1956
# 1476    7178                                  Great Gatsby, The  Drama  1974
# 2368    6786                           Kiss of the Spider Woman  Drama  1985
# 2851    1186                           Sex, Lies, and Videotape  Drama  1988
# 3200    4787                                    Little Man Tate  Drama  1990
# 3660     282                                               Nell  Drama  1994
# 3674     309  Red Firecracker, Green Firecracker (Pao Da Shu...  Drama  1993
# 4371    1545                                            Ponette  Drama  1995
# ...

# %% [markdown]
# ### Funciones de agregación
# Las funciones de agregación son funciones que toman una serie de entradas y devuelven una única salida.
#
# Las más comunes que utilizamos en Pandas son las que toman series numéricas y devuelven un estadístico de interés, como la media.

# %%
print(df_movies["rating"].mean())
print(df_movies["rating"].min())
print(df_movies["rating"].max())
# Out:
# 5.469917808219178
# 1
# 10

# %% [markdown]
# El método describe() proporciona un informe de estadísticas resumidas sobre una serie numérica dada

# %%
df_movies["rating"].describe()
# Out:
# count    9125.000000
# mean        5.469918
# std         2.881082
# min         1.000000
# 25%         3.000000
# 50%         5.000000
# 75%         8.000000
# max        10.000000
# Name: rating, dtype: float64

# %% [markdown]
# También podemos usar este método en un DataFrame para verlo aplicado a cada columna numérica.

# %%
df_movies[["rating", "rotton_tomato"]].describe()
# Out:
#             rating  rotton_tomato
# count  9125.000000    9125.000000
# mean      5.469918      75.147397
# std       2.881082      14.812139
# min       1.000000      50.000000
# 25%       3.000000      62.000000
# 50%       5.000000      75.000000
# 75%       8.000000      88.000000
# max      10.000000     100.000000

# %%
df_movies[["rating", "rotton_tomato"]].describe().round(2)
# Out:
#         rating  rotton_tomato
# count  9125.00        9125.00
# mean      5.47          75.15
# std       2.88          14.81
# min       1.00          50.00
# 25%       3.00          62.00
# 50%       5.00          75.00
# 75%       8.00          88.00
# max      10.00         100.00

# %% [markdown]
# ### Agrupaciones
# A veces, querremos ver los resultados de una función de agregación por categoría en una columna no numérica. Para ello, primero usamos el método groupby([columns]) y especificamos la categoría por la que queremos agrupar.

# %%
df_movies.groupby(["genres"])

# %%
df_movies_per_genres = df_movies.groupby(["genres"])[["movie"]].count()

df_movies_per_genres
# Out:
#                                      movie
# genres
# (no genres listed)                      18
# Action                                  39
# Action|Adventure                        32
# Action|Adventure|Animation              14
# Action|Adventure|Animation|Children      3
# ...                                    ...
# Sci-Fi|Thriller                         13
# Sci-Fi|Thriller|IMAX                     1
# Thriller                                74
# War                                      6
# Western                                 31
#
# [902 rows x 1 columns]

# %%
df_movies_per_genres_top_ten = df_movies.groupby(["genres"]).count().head(10)[["movie"]]

df_movies_per_genres_top_ten
# Out:
#                                                     movie
# genres
# (no genres listed)                                     18
# Action                                                 39
# Action|Adventure                                       32
# Action|Adventure|Animation                             14
# Action|Adventure|Animation|Children                     3
# Action|Adventure|Animation|Children|Comedy              4
# Action|Adventure|Animation|Children|Comedy|Fantasy      2
# Action|Adventure|Animation|Children|Comedy|IMAX         2
# Action|Adventure|Animation|Children|Comedy|Romance      1
# Action|Adventure|Animation|Children|Comedy|Sci-Fi       2

# %% [markdown]
# ### Reset index
# Normalmente, los índices de fila son números, pero también pueden tener nombre.

# %%
df_movies_per_genres.columns
# Out:
# Index(['movie'], dtype='object')

# %% [markdown]
# Para restablecer el índice a números y mover el índice actual a una columna, usamos reset_index()

# %%
df_movies_per_genres_reset = df_movies_per_genres.reset_index()

df_movies_per_genres_reset
# Out:
#                                   genres  movie
# 0                     (no genres listed)     18
# 1                                 Action     39
# 2                       Action|Adventure     32
# 3             Action|Adventure|Animation     14
# 4    Action|Adventure|Animation|Children      3
# ..                                   ...    ...
# 897                      Sci-Fi|Thriller     13
# 898                 Sci-Fi|Thriller|IMAX      1
# 899                             Thriller     74
# 900                                  War      6
# 901                              Western     31
#
# [902 rows x 2 columns]

# %% [markdown]
# ### Ordenación
# Pandas proporciona un método sort_values() para ordenar las filas en un DataFrame o Series.
#
# Si se llama en un DataFrame, debe especificar por qué columna está ordenando, como esto: df.sort_values([col]).

# %%
df_movies.sort_values(["rating"])
# Out:
#        movie                                             title  \
# 9092  159755                Popstar: Never Stop Never Stopping
# 9091  159690  Teenage Mutant Ninja Turtles: Out of the Shadows
# 33      3742                               Battleship Potemkin
# 20     83361                                     Paleface, The
# 1002    7771                   Zorba the Greek (Alexis Zorbas)
# ...      ...                                               ...
# 1243   59834                                        100 Rifles
# 7295   59725                                  Sex and the City
# 9108  161918                      Sharknado 4: The 4th Awakens
# 9094  159972                           Approaching the Unknown
# 30      3133                                           Go West
#
#                               genres  year  rating  rotton_tomato
# 9092                          Comedy  2016       1             84
# 9091         Action|Adventure|Comedy  2016       1             93
# ...

# %% [markdown]
# Si se aplica a una Serie solo hay una columna, por lo que no es necesario especificar

# %%
df_movies_per_genres["movie"].sort_values()
# Out:
# genres
# Action|Adventure|Animation|Children|Fantasy|Sci-Fi           1
# Action|Adventure|Animation|Children|Fantasy                  1
# Action|Adventure|Animation|Children|Comedy|Western           1
# Action|Adventure|Animation|Children|Comedy|Sci-Fi|IMAX       1
# Action|Adventure|Animation|Children|Comedy|Romance           1
#                                                           ...
# Drama|Romance                                              356
# Documentary                                                365
# Comedy|Drama                                               425
# Comedy                                                     809
# Drama                                                     1170
# Name: movie, Length: 902, dtype: int64

# %% [markdown]
# Por defecto, sort_values() ordena en orden ascendente. Puede especificar el parámetro "ascending=False" para cambiarlo a orden descendente.

# %%
df_movies_per_genres["movie"].sort_values(ascending=False)
# Out:
# genres
# Drama                                              1170
# Comedy                                              809
# Comedy|Drama                                        425
# Documentary                                         365
# Drama|Romance                                       356
#                                                    ...
# Action|Adventure|Children|Comedy|Fantasy|Sci-Fi       1
# Action|Adventure|Animation|Sci-Fi|Thriller            1
# Mystery|Sci-Fi|Thriller|IMAX                          1
# Mystery|Sci-Fi                                        1
# Action|Adventure|Animation|Comedy|Sci-Fi              1
# Name: movie, Length: 902, dtype: int64

# %% [markdown]
# ### NaN
# Quizás hayas notado que nuestro DataFrame contiene valores NaN. Estos indican un valor faltante.
#
# Existen varias maneras de gestionar los valores faltantes. A menudo, la presencia de estos valores causa problemas en las tareas computacionales.
#
# Primero, podemos comprobarlo usando el método isna(), alias de isnull(), y el método sum() para contar el número de valores NaN presentes.

# %%
df_movies_nan = df_movies[["movie", "title", "genres", "rating", "rotton_tomato"]]

df_movies_nan
# Out:
#        movie                                             title  \
# 0     108583                               Fawlty Towers (1975
# 1      32898     Trip to the Moon, A (Voyage dans la lune, Le)
# 2       7065                            Birth of a Nation, The
# 3       7243  Intolerance: Love's Struggle Throughout the Ages
# 4      62383                      20,000 Leagues Under the Sea
# ...      ...                                               ...
# 9120  110748                                       Wake Wood (
# 9121  143410                                              Hyen
# 9122  151307                                The Lovers and the
# 9123  162376                                          Stranger
# 9124  164979                                   Women of '69, U
#
#                                genres  rating  rotton_tomato
# 0                              Comedy       1             54
# 1     Action|Adventure|Fantasy|Sci-Fi       7             80
# ...

# %%
df_movies_nan.isna().sum()
# Out:
# movie            0
# title            0
# genres           0
# rating           0
# rotton_tomato    0
# dtype: int64

# %% [markdown]
# ### Dropping NaN
# Una forma de gestionar NaN es descartar todas las filas que tengan valores NaN. Podemos usar el método dropna() para ello.

# %%
df_movies_nan.dropna()
# Out:
#        movie                                             title  \
# 0     108583                               Fawlty Towers (1975
# 1      32898     Trip to the Moon, A (Voyage dans la lune, Le)
# 2       7065                            Birth of a Nation, The
# 3       7243  Intolerance: Love's Struggle Throughout the Ages
# 4      62383                      20,000 Leagues Under the Sea
# ...      ...                                               ...
# 9120  110748                                       Wake Wood (
# 9121  143410                                              Hyen
# 9122  151307                                The Lovers and the
# 9123  162376                                          Stranger
# 9124  164979                                   Women of '69, U
#
#                                genres  rating  rotton_tomato
# 0                              Comedy       1             54
# 1     Action|Adventure|Fantasy|Sci-Fi       7             80
# ...

# %% [markdown]
# ### Impute columns
# Sin embargo, al eliminar registros, se descarta mucha información.
#
# En lugar de eliminar filas con valores faltantes, podemos imputar los valores faltantes usando fillna() y especificando un valor predeterminado.

# %%
df_movies_nan.fillna("Missing")
# Out:
#        movie                                             title  \
# 0     108583                               Fawlty Towers (1975
# 1      32898     Trip to the Moon, A (Voyage dans la lune, Le)
# 2       7065                            Birth of a Nation, The
# 3       7243  Intolerance: Love's Struggle Throughout the Ages
# 4      62383                      20,000 Leagues Under the Sea
# ...      ...                                               ...
# 9120  110748                                       Wake Wood (
# 9121  143410                                              Hyen
# 9122  151307                                The Lovers and the
# 9123  162376                                          Stranger
# 9124  164979                                   Women of '69, U
#
#                                genres  rating  rotton_tomato
# 0                              Comedy       1             54
# 1     Action|Adventure|Fantasy|Sci-Fi       7             80
# ...

# %% [markdown]
# A menudo, queremos imputar diferentes valores a distintas columnas. Por ejemplo, con valores numéricos, podemos imputar con la media, la mediana, etc. Para características categóricas, es común imputar con la moda o una categoría especial.
#
# Podemos pasar un diccionario a fillna() que tenga como clave los nombres de las columnas y como valor el valor con el que se imputará la columna.
#
# Opcionalmente, puede especificar inplace=True si desea actualizar el DataFrame subyacente.

# %%
df_movies_nan.fillna({"rating": 0, "rotton_tomato": 50}, inplace=False)
# Out:
#        movie                                             title  \
# 0     108583                               Fawlty Towers (1975
# 1      32898     Trip to the Moon, A (Voyage dans la lune, Le)
# 2       7065                            Birth of a Nation, The
# 3       7243  Intolerance: Love's Struggle Throughout the Ages
# 4      62383                      20,000 Leagues Under the Sea
# ...      ...                                               ...
# 9120  110748                                       Wake Wood (
# 9121  143410                                              Hyen
# 9122  151307                                The Lovers and the
# 9123  162376                                          Stranger
# 9124  164979                                   Women of '69, U
#
#                                genres  rating  rotton_tomato
# 0                              Comedy       1             54
# 1     Action|Adventure|Fantasy|Sci-Fi       7             80
# ...

# %% [markdown]
# ### Escribir en CSV
# Podemos escribir un DataFrame de Pandas en un archivo CSV como se muestra a continuación usando el método to_csv()

# %%
file_path_output = "/content/gdrive/MyDrive/datasources/movies_updated.csv"

df_movies.to_csv(file_path_output, index=False)
