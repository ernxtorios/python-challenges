# %% [markdown]
# <a href="https://colab.research.google.com/github/ernxtorios/python-challenges/blob/main/data_visualization.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from google.colab import drive

# %%
drive.mount("/content/gdrive/")
# Out:
# Mounted at /content/gdrive/

# %%
import pandas as pd

# %%
file_path_movies = "/content/gdrive/MyDrive/datasources/movies.csv"

df_movies = pd.read_csv(file_path_movies)

df_movies
# Out:
#        movie                                             title  \
# 0     108583                               Fawlty Towers (1975
# 1      32898     Trip to the Moon, A (Voyage dans la lune, Le)
# 2       7065                            Birth of a Nation, The
# 3       7243  Intolerance: Love's Struggle Throughout the Ages
# 4      62383                      20,000 Leagues Under the Sea
# ...      ...                                               ...
# 9120  110748                                       Wake Wood (
# 9121  143410                                              Hyen
# 9122  151307                                The Lovers and the
# 9123  162376                                          Stranger
# 9124  164979                                   Women of '69, U
#
#                                genres  year  Rating  Rotton Tomato
# 0                              Comedy -1980       1             54
# 1     Action|Adventure|Fantasy|Sci-Fi  1902       7             80
# ...

# %%
display(df_movies)
# Out:
#        movie                                             title  \
# 0     108583                               Fawlty Towers (1975
# 1      32898     Trip to the Moon, A (Voyage dans la lune, Le)
# 2       7065                            Birth of a Nation, The
# 3       7243  Intolerance: Love's Struggle Throughout the Ages
# 4      62383                      20,000 Leagues Under the Sea
# ...      ...                                               ...
# 9120  110748                                       Wake Wood (
# 9121  143410                                              Hyen
# 9122  151307                                The Lovers and the
# 9123  162376                                          Stranger
# 9124  164979                                   Women of '69, U
#
#                                genres  year  Rating  Rotton Tomato
# 0                              Comedy -1980       1             54
# 1     Action|Adventure|Fantasy|Sci-Fi  1902       7             80
# ...

# %%
df_movies["Rotton Tomato"].hist()
# Out:
# <Axes: >

# %%
df_movies["Rotton Tomato"].hist(bins=20)
# Out:
# <Axes: >

# %%
df_movies.boxplot(["Rotton Tomato", "Rating"])
# Out:
# <Axes: >

# %%
import seaborn as sns

# %%
sns.scatterplot(data=df_movies, x="Rating", y="Rotton Tomato")
# Out:
# <Axes: xlabel='Rating', ylabel='Rotton Tomato'>

# %%
sns.regplot(data=df_movies, x="Rating", y="Rotton Tomato")
# Out:
# <Axes: xlabel='Rating', ylabel='Rotton Tomato'>
